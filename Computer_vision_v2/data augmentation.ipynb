# %%
#%pip install imageio
#%pip install imgaug
#%matplotlib inline
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
import os
import cv2


# C:\Users\Stephen Pangga\Desktop\Computer_vision_v2\Resize tubes Organize Backup
generalpath = "/Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test"
inputpath = os.path.join(generalpath)
outputpath = os.path.join(generalpath, 'TT')

imageCountOfLetter = 0

for subdir, dirs, files in os.walk(inputpath):
    for filename in files:
        if filename.endswith('.jpg'):

            imgpath = os.path.join(subdir, filename)
            filename_stripped = filename.strip('.jpg')             
            outputfilepath = os.path.join(subdir, filename_stripped).replace('v1', 'v2 (augmented)')   

            print(imgpath)
            print(filename_stripped)
            print(outputfilepath)


            # 1 Default img
            defaultimg = imageio.imread(imgpath)
            img1 = cv2.resize(defaultimg, (220, 380))
            img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
            cv2.imwrite(outputfilepath + ".jpg", img)

            # 2 Rotate
            rotate=iaa.Affine(rotate=(-30, 30))
            rotated_image=rotate.augment_image(img)
            cv2.imwrite(outputfilepath + "_rotated.jpg", rotated_image)
            
            # 3 Rotate
            rotate=iaa.Affine(rotate=(30, -30))
            rotated_image=rotate.augment_image(img)
            cv2.imwrite(outputfilepath + "_rotated_2.jpg", rotated_image)

            rotate=iaa.Affine(rotate=(-50, 50))
            rotated_image=rotate.augment_image(img)
            cv2.imwrite(outputfilepath + "_rotated_3.jpg", rotated_image)

            rotate=iaa.Affine(rotate=(50, -50))
            rotated_image=rotate.augment_image(img)
            cv2.imwrite(outputfilepath + "_rotated_4.jpg", rotated_image)

            # 3 Gauss noise
            gaussian_noise=iaa.AdditiveGaussianNoise(10,20)
            noise_image=gaussian_noise.augment_image(img)
            cv2.imwrite(outputfilepath + "_gauss_noise.jpg", noise_image)

            gaussian_noise=iaa.AdditiveGaussianNoise(20,10)
            noise_image=gaussian_noise.augment_image(img)
            cv2.imwrite(outputfilepath + "_gauss_noise_1.jpg", noise_image)

            # 4 Cropping
            crop = iaa.Crop(percent=(0, 0.3)) # crop image
            crop_image = crop.augment_image(img)
            cv2.imwrite(outputfilepath + "_crop.jpg", crop_image)

            # 5 Shearing
            shear = iaa.Affine(shear=(5))
            shear_image = shear.augment_image(img)
            cv2.imwrite(outputfilepath + "_shear.jpg", shear_image)

            # 6 Flipping horizontally
            flip_hr = iaa.Fliplr(p=1.0)
            flip_hr_image = flip_hr.augment_image(img)
            cv2.imwrite(outputfilepath + "_flip_hr.jpg", flip_hr_image)

            # 7 Flip vertically
            flip_vr = iaa.Flipud(p=1.0)
            flip_vr_image= flip_vr.augment_image(img)
            cv2.imwrite(outputfilepath + "_flip_vr.jpg", flip_vr_image)

            # 8 Change brightness
            contrast = iaa.GammaContrast(gamma=2.0)
            contrast_image = contrast.augment_image(img)
            cv2.imwrite(outputfilepath + "_constrast.jpg", contrast_image)

            # 9 Scaling image
            scale_im = iaa.Affine(scale={"x": (1.5, 1.0), "y": (1.5, 1.0)})
            scale_image = scale_im.augment_image(img)
            cv2.imwrite(outputfilepath + "_scaled.jpg", scale_image)

            # 10 Blur image
            blurred_img = cv2.blur(img, (5, 5))
            cv2.imwrite(outputfilepath + "_blurred.jpg", blurred_img)

            blurred_img = cv2.blur(img, (3, 3))
            cv2.imwrite(outputfilepath + "_blurred3.jpg", blurred_img)
# Out:
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1.jpg
# BD-Vacutainer1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1
# C:\Users\Stephen Pangga\AppData\Local\Temp\ipykernel_24636\27462009.py:37: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   defaultimg = imageio.imread(imgpath)
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1b.jpg
# BD-Vacutainer1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1c.jpg
# BD-Vacutainer1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1d.jpg
# BD-Vacutainer1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1e.jpg
# BD-Vacutainer1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2.jpg
# BD-Vacutainer2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2b.jpg
# BD-Vacutainer2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2c.jpg
# BD-Vacutainer2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2d.jpg
# BD-Vacutainer2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\BD-Vacutainer\BD-Vacutainer2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1.jpg
# EDTA(K2)1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1b.jpg
# EDTA(K2)1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1c.jpg
# EDTA(K2)1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1d.jpg
# EDTA(K2)1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2.jpg
# EDTA(K2)2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2b.jpg
# EDTA(K2)2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2c.jpg
# EDTA(K2)2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2d.jpg
# EDTA(K2)2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3.jpg
# EDTA(K2)3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3b.jpg
# EDTA(K2)3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3c.jpg
# EDTA(K2)3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3d.jpg
# EDTA(K2)3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\EDTA(K2)\EDTA(K2)3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1.jpg
# Monovette1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1b.jpg
# Monovette1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1c.jpg
# Monovette1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1d.jpg
# Monovette1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2.jpg
# Monovette2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2b.jpg
# Monovette2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2c.jpg
# Monovette2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2d.jpg
# Monovette2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Monovette\Monovette2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1.jpg
# PLAIN1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1b.jpg
# PLAIN1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1c.jpg
# PLAIN1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1d.jpg
# PLAIN1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Plain\PLAIN1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1.jpg
# SGS1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1b.jpg
# SGS1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1c.jpg
# SGS1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1d.jpg
# SGS1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1e.jpg
# SGS1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1f.jpg
# SGS1f
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\SGS\SGS1f
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1.jpg
# Vacuette1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1b.jpg
# Vacuette1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1c.jpg
# Vacuette1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1d.jpg
# Vacuette1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2.jpg
# Vacuette2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2b.jpg
# Vacuette2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2c.jpg
# Vacuette2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2d.jpg
# Vacuette2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3.jpg
# Vacuette3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3b.jpg
# Vacuette3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3c.jpg
# Vacuette3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3d.jpg
# Vacuette3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacuette\Vacuette3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1.jpg
# Vacutest1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1b.jpg
# Vacutest1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1c.jpg
# Vacutest1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1d.jpg
# Vacutest1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2.jpg
# Vacutest2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2b.jpg
# Vacutest2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2c.jpg
# Vacutest2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2d.jpg
# Vacutest2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3.jpg
# Vacutest3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3b.jpg
# Vacutest3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3c.jpg
# Vacutest3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3d.jpg
# Vacutest3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Vacutest\Vacutest3d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1.jpg
# Venosafe1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1b.jpg
# Venosafe1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1c.jpg
# Venosafe1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1d.jpg
# Venosafe1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1e.jpg
# Venosafe1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe1e
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2.jpg
# Venosafe2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2b.jpg
# Venosafe2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2b
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2c.jpg
# Venosafe2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2c
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2d.jpg
# Venosafe2d
# /Users/Stephen Pangga/Desktop/Computer_vision_v2/Test test\Venosafe\Venosafe2d
